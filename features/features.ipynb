# %% [markdown]
# # Идеи на реализацию
#
# ---
#
# 🔥 Идеи для развития Spray Zone (Frontend + Backend + UX)
#
# 1. Вместо localStorage — полноценная авторизация <br />
# 	•	Регистрация / вход <br />
# 	•	Корзина и заказы хранятся на сервере <br />
# 	•	У пользователя появляется профиль <br />
# Это позволит пользоваться корзиной с разных устройств.
#
# ---
#
# 2. Категории и фильтры товаров <br />
# 	•	Фильтр по брендам <br />
# 	•	Фильтр по цене <br />
# 	•	Фильтр по типу (например, краска, грунт и т.д.) <br />
# 	•	Поиск по названию <br />
#
# Без этого магазин не масштабируется.
#
# ---
#
# 3. Страница товара (Product Page) <br />
# 	•	Большая фотография <br />
# 	•	Подробное описание <br />
# 	•	Наличие <br />
# 	•	Кнопка «Добавить в корзину» <br />
# 	•	Похожие товары <br />
#
# Повышает конверсию.
#
# ---
#
# 4. Система избранного (Favorites / Wishlist) <br />
# 	•	Хранение в localStorage или в аккаунте <br />
# 	•	Отдельная страница «Избранное» <br />
#
# ---
#
# 5. Админ-панель
#
# Чтобы ты мог сам: <br />
# 	•	добавлять товары <br />
# 	•	редактировать товары <br />
# 	•	загружать изображения <br />
# 	•	менять цены <br />
#
# Можно сделать на React + простые CRUD-запросы.
#
# ---
#
# 6. Обработка заказов
#
# Добавить модель Order: <br />
# 	•	товары <br />
# 	•	количество <br />
# 	•	сумма <br />
# 	•	дата заказа <br />
# 	•	статус заказа: pending / shipped / delivered <br />
#
# ---
#
# 7. Рейтинг и отзывы к товарам
#
# Пользователи могут: <br />
# 	•	ставить звёзды <br />
# 	•	писать отзывы <br />
# 	•	загружать фото <br />
#
# ---
#
# 8. Более красивый UI <br />
# 	•	Анимации (Framer Motion) <br />
# 	•	Skeletons при загрузке <br />
# 	•	Улучшенное оформление карточек товаров <br />
# 	•	Красивый layout корзины <br />
#
# ---
#
# 9. Система промокодов <br />
# 	•	промо «SPRAY10» → скидка 10% <br />
# 	•	дата истечения <br />
# 	•	ограничение на количество применений <br />
#
# ---
#
# 10. Панель аналитики для админа
#
# Графики в реальном времени: <br />
# 	•	топовые товары <br />
# 	•	выручка <br />
# 	•	активность пользователей <br />
# 	•	количество заказов по дням <br />
#
# Можно через Chart.js или Recharts.
#
# ---
#
# 11. Тёмная/светлая тема <br />
#
# Профильный переключатель.
#
# ---
#
# 12. Улучшение backend API <br />
# 	•	валидация через Zod / Joi <br />
# 	•	обработка ошибок <br />
# 	•	логирование <br />
# 	•	защита API через JWT <br />
#
# ---
#
# 13. Поиск с подсказками
#
# Как у магазинов: <br />
# 	•	пользователь вводит «cr» <br />
# 	•	подсказки: “cream spray”, “chrome spray” <br />
#
# ---
#
# 14. История просмотра товаров <br />
#
# Чтобы вернуться к тому, что смотрел.
#
# ---
#
# 15. Docker + деплой <br />
# 	•	Docker Compose для фронта и бэка <br />
# 	•	Деплой на Render / Railway / Vercel <br />
# 	•	Настройка CI/CD <br />
#
# ---

# %%
def sum(a, b):
    return a+b


print(sum(int(input('a = ')), int(input('b = '))))
